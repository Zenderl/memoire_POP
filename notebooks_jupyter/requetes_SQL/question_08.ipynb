# %% [markdown]
# BESOIN DE FAIRE UN DEROULEMENT CHRONOLOGIQUE AVEC UN POURCENTAGE H/F (5 périodes de 2ans)

# %% [markdown]
# Q8
# participation au comité cantonal entre 1974 et 1985

# %% [markdown]
# 8.1 membres du comité cantonal entre 1974 et 1985

# %%
import sqlite3
import pandas

connection = sqlite3.connect('C:/Users/LZender/Documents/Travail/unine/histoire/mémoire/AEN/grand_conseil/memoire_POP/liste_grand_conseil.db')


cursor = connection.cursor()

df = pandas.read_sql("""
SELECT pe.nom as nom, pe.prenom as prenom, pe.genre as genre, f.nom as delegue, e.annee_debut as debut, e.annee_fin as fin FROM personne as pe
LEFT JOIN exercice as e ON e.fk_personne = pe.pk_personne
LEFT JOIN fonction as f ON f.pk_fonction = e.fk_fonction

where f.pk_fonction is not null AND f.nom ='comite_cantonal'
group by pk_personne
order by debut ASC
""", connection)

df.head(1000)
# Out:
#                 nom           prenom genre          delegue   debut     fin
# 0       blant-mojon          colette     F  comite_cantonal  1974.0  1978.0
# 1   corswant_hirsch         marcelle     F  comite_cantonal  1974.0  1983.0
# 2            beuret           helene     F  comite_cantonal  1974.0  1978.0
# 3             greub           margot     F  comite_cantonal  1974.0  1982.0
# 4       Eplattenier             lily     F  comite_cantonal  1974.0  1978.0
# 5           duvanel             jean     M  comite_cantonal  1974.0  1974.0
# 6           hirschi           gerard     M  comite_cantonal  1974.0  1978.0
# 7           guillod          jacques     M  comite_cantonal  1974.0  1978.0
# 8              dind          jacques     M  comite_cantonal  1974.0  1974.0
# 9           gremaud           armand     M  comite_cantonal  1974.0  1974.0
# 10      vuilleumier          raymond     M  comite_cantonal  1974.0  1974.0
# 11           lagger             paul     M  comite_cantonal  1974.0  1974.0
# 12           blaser         frederic     M  comite_cantonal  1974.0  1985.0
# 13           blaser             jean     M  comite_cantonal  1974.0  1975.0
# 14            donze          laurent     M  comite_cantonal  1974.0  1975.0
# 15            emery           michel     M  comite_cantonal  1974.0  1978.0
# 16           roulet          charles     M  comite_cantonal  1974.0  1974.0
# 17          steiger             jean     M  comite_cantonal  1974.0  1985.0
# 18         broillet          etienne     M  comite_cantonal  1974.0  1978.0
# 19           roulet           pierre     M  comite_cantonal  1974.0  1982.0
# 20            blant             rene     M  comite_cantonal  1974.0  1975.0
# 21        lengacher            henri     M  comite_cantonal  1974.0  1978.0
# 22           berger           gerard     M  comite_cantonal  1974.0  1985.0
# 23           roulet          ginette     F  comite_cantonal  1974.0  1974.0
# 24       leimgruber           claude     M  comite_cantonal  1974.0  1985.0
# 25         bringolf           gerald     M  comite_cantonal  1974.0  1974.0
# 26       steigmeier             luce     F  comite_cantonal  1975.0  1976.0
# 27            greub            andre     M  comite_cantonal  1975.0  1983.0
# 28          debieux           charly     M  comite_cantonal  1975.0  1985.0
# 29         bringolf            alain     M  comite_cantonal  1975.0  1985.0
# 30         gassmann            heinz     M  comite_cantonal  1975.0  1978.0
# 31          bottani             anna     F  comite_cantonal  1976.0  1977.0
# 32          humbert  fred-alain_nago     M  comite_cantonal  1976.0  1982.0
# 33           grasso        elisabeth     F  comite_cantonal  1976.0  1978.0
# 34         ramseyer           gerald     M  comite_cantonal  1976.0  1978.0
# 35        vuillemin          marlyse     F  comite_cantonal  1976.0  1976.0
# 36  corswant_boegli         lucienne     F  comite_cantonal  1977.0  1978.0
# 37          perinat           maryse     F  comite_cantonal  1979.0  1982.0
# 38             kuhn           joelle     M  comite_cantonal  1979.0  1985.0
# 39       schulthess           daniel     M  comite_cantonal  1979.0  1982.0
# 40           blaser      jean-pierre     M  comite_cantonal  1979.0  1979.0
# 41          gerussi     marie-claire     F  comite_cantonal  1979.0  1985.0
# 42            bolle            louis     M  comite_cantonal  1979.0  1982.0
# 43         bonfanti          gabriel     M  comite_cantonal  1979.0  1984.0
# 44            boder            alain     M  comite_cantonal  1979.0  1982.0
# 45          bottani           arnold     M  comite_cantonal  1983.0  1985.0
# 46   de_la_reusille           charly     M  comite_cantonal  1983.0  1985.0
# 47  bigarini_gether          suzanne     F  comite_cantonal  1983.0  1985.0
# 48        camponovo             remy     M  comite_cantonal  1983.0  1984.0
# 49            belza           firmin     M  comite_cantonal  1983.0  1985.0
# 50        bloudanis          nicolas     M  comite_cantonal  1983.0  1984.0
# 51       froidevaux           nicole     F  comite_cantonal  1983.0  1985.0
# 52           werner            andre     M  comite_cantonal  1983.0  1985.0

# %% [markdown]
# 8.1.1 membres femmes du comité cantonal entre 1974 et 1985

# %%
import sqlite3
import pandas

connection = sqlite3.connect('C:/Users/LZender/Documents/Travail/unine/histoire/mémoire/AEN/grand_conseil/memoire_POP/liste_grand_conseil.db')


cursor = connection.cursor()

df = pandas.read_sql("""
SELECT pe.nom as nom, pe.prenom as prenom, pe.genre as genre, f.nom as delegue, e.annee_debut as debut, e.annee_fin as fin FROM personne as pe
LEFT JOIN exercice as e ON e.fk_personne = pe.pk_personne
LEFT JOIN fonction as f ON f.pk_fonction = e.fk_fonction

where f.pk_fonction is not null AND f.nom ='comite_cantonal'AND pe.genre='F'
group by pk_personne
order by debut ASC
""", connection)

df.head(1000)
# Out:
#                 nom        prenom genre          delegue   debut     fin
# 0       blant-mojon       colette     F  comite_cantonal  1974.0  1978.0
# 1   corswant_hirsch      marcelle     F  comite_cantonal  1974.0  1983.0
# 2            beuret        helene     F  comite_cantonal  1974.0  1978.0
# 3             greub        margot     F  comite_cantonal  1974.0  1982.0
# 4       Eplattenier          lily     F  comite_cantonal  1974.0  1978.0
# 5            roulet       ginette     F  comite_cantonal  1974.0  1974.0
# 6        steigmeier          luce     F  comite_cantonal  1975.0  1976.0
# 7           bottani          anna     F  comite_cantonal  1976.0  1977.0
# 8            grasso     elisabeth     F  comite_cantonal  1976.0  1978.0
# 9         vuillemin       marlyse     F  comite_cantonal  1976.0  1976.0
# 10  corswant_boegli      lucienne     F  comite_cantonal  1977.0  1978.0
# 11          perinat        maryse     F  comite_cantonal  1979.0  1982.0
# 12          gerussi  marie-claire     F  comite_cantonal  1979.0  1985.0
# 13  bigarini_gether       suzanne     F  comite_cantonal  1983.0  1985.0
# 14       froidevaux        nicole     F  comite_cantonal  1983.0  1985.0
